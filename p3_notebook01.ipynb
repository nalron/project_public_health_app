# %% [markdown]
# # Projet d'application en lien avec l'alimentation
#
# Etude data - Projet 3 - Nalron (Octobre 2020) OpenClassrooms / CentraleSupélec
#
# Traitement des données sur Jupyter Notebook (Distribution Anaconda)
#
# Etude réalisée en langage Python
#
# *Data source* : [Open Food Fact](https://fr.openfoodfacts.org/data) -
# *Variables info* : [Open Food Variables](https://world.openfoodfacts.org/data/data-fields.txt)

# %% [markdown]
# ---

# %% [markdown]
# L'agence [Santé publique France](http://www.santepubliquefrance.fr/) a lancé un appel à projets pour trouver des idées innovantes d’applications en lien avec l'alimentation. L'objectif est d'y participer et de proposer une idée d’application.

# %% [markdown]
# ## Les données
# **Extrait de l’appel à projets :**
#
# Le jeu de données Open Food Fact est disponible sur le site officiel. Les variables sont définies à cette adresse.
#
# Les champs sont séparés en quatre sections :
#
# - Les informations générales sur la fiche du produit : nom, date de modification, etc.
# - Un ensemble de tags : catégorie du produit, localisation, origine, etc.
# - Les ingrédients composant les produits et leurs additifs éventuels.
# - Des informations nutritionnelles : quantité en grammes d’un nutriment pour 100 grammes du produit.

# %% [markdown]
# ---

# %% [markdown]
# ## Application proposée
# ## "De nutri-score à NOVA, des outils pour s’y retrouver… "
# **Le principe est simple, pouvoir répondre à la demande des consommateurs par un double affichage : Nutri-score + classification NOVA.**

# %% [markdown]
# ### NUTRI-SCORE : COMMENT ÇA MARCHE ?
# Le Nutri-Score prend en compte pour 100 grammes de produit, la teneur en nutriments et aliments à favoriser : fibres, protéines, fruits et légumes ; il tient compte des nutriments à limiter (énergie, acides gras saturés, sucres, sel). Après calcul, le score obtenu permet d’attribuer une lettre (A à E) et une couleur à chaque produit sous forme d’un logo à 5 couleurs. Le logo désigne ainsi en 5 niveaux la qualité nutritionnelle des aliments. Apposé sur la face avant des produits emballés, il permet une comparaison entre produits du même rayon et par conséquent aide le consommateur à choisir des produits de meilleure qualité nutritionnelle.

# %% [markdown]
# ![Nutriscore](p3_image/nutriscore.png)

# %% [markdown]
# **Le ”A” est attribué aux produits les plus favorables pour la santé tandis que la ”E” identifie les moins favorables.**\
# Grâce au logo Nutri-Score, le consommateur fait rapidement la comparaison entre les produits alignés dans un même rayon.

# %% [markdown]
# ### LA CLASSIFICATION NOVA : UN COMPLÉMENT AU NUTRI-SCORE
# La classification NOVA (qui n’est pas un acronyme), mise au point par le Professeur Monteiro et son équipe au Brésil, est une répartition des aliments en 4 groupes en fonction du degré de transformation qu’ils ont subi. Leur objectif était de trouver une indication simple, accessible aux moins favorisés (y compris les analphabètes), pour comprendre les différentes sortes d’aliments à leur disposition. Rappelons que le Brésil est le pays où l’incidence de l’obésité chez les enfants est le plus élevé au monde. Ces chercheurs ont démontré l’efficience de cette classification qui se résumé en 4 catégories : 1 à 4, du plus simple au plus transformé. Du plus naturel au plus complexe avec additifs et de multiples étapes de fabrication.

# %% [markdown]
# ![nova](p3_00_image/nova.png)

# %% [markdown]
# **1 à 4, du plus simple au plus transformé.**\
# Du plus naturel au plus complexe avec additifs et de multiples étapes de fabrication.

# %% [markdown]
# ***L'objectif est d'identifier des arguments justifiant la faisabilité (ou non) de l’application à partir des données Open Food Facts.***

# %% [markdown]
# ---

# %%
import pandas as pd
import datetime as dt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pd.set_option('display.max_rows', 1000)

# %%
openfoodfacts = pd.read_csv('p3_00_data/en.openfoodfacts.org.products.csv', 
                            sep='/t', delimiter=';', encoding='utf-8', engine='python')
openfoodfacts.head()
# Out:
#                    code                                                url  \
# 0                    17  http://world-en.openfoodfacts.org/product/0000...
# 1                    31  http://world-en.openfoodfacts.org/product/0000...
# 2    000000000003327986  http://world-en.openfoodfacts.org/product/0000...
# 3                   100  http://world-en.openfoodfacts.org/product/0000...
# 4  00000000001111111111  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                     kiliweb  1574175736  2019-11-19T15:02:16Z
# 3                       del51  1444572561  2015-10-11T14:09:21Z
# 4  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
#
#    last_modified_t last_modified_datetime                  product_name  \
# 0       1561463718   2019-06-25T11:55:18Z              Vitória crackers
# 1       1539464817   2018-10-13T21:06:57Z                         Cacao
# 2       1574175737   2019-11-19T15:02:17Z     Filetes de pollo empanado
# 3       1444659212   2015-10-12T14:13:32Z   moutarde au moût de raisin
# 4       1560020173   2019-06-08T18:56:13Z                       Sfiudwx
#
#   generic_name quantity  ... carbon-footprint-from-meat-or-fish_100g  \
# 0          NaN      NaN  ...                                     NaN
# 1          NaN    130 g  ...                                     NaN
# 2          NaN      NaN  ...                                     NaN
# 3          NaN     100g  ...                                     NaN
# 4          NaN    dgesc  ...                                     NaN
#
#   nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# 0                     NaN                     NaN                 NaN
# 1                     NaN                     NaN                 NaN
# 2                     NaN                     NaN                 NaN
# 3                    18.0                     NaN                 NaN
# 4                     NaN                     NaN                 NaN
#
#   water-hardness_100g choline_100g phylloquinone_100g beta-glucan_100g  \
# 0                 NaN          NaN                NaN              NaN
# 1                 NaN          NaN                NaN              NaN
# 2                 NaN          NaN                NaN              NaN
# 3                 NaN          NaN                NaN              NaN
# 4                 NaN          NaN                NaN              NaN
#
#   inositol_100g carnitine_100g
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
#
# [5 rows x 181 columns]

# %% [markdown]
# ### Informations descriptives globales de l'échantillon
# Affichage de quelques informations représentatives de l'échantillon : taille de l'échantillon, type de variables, valeurs manquantes, doublons, etc…

# %%
openfoodfacts.shape
# Out:
# (32309, 181)

# %%
openfoodfacts.dtypes
# Out:
# code                                           object
# url                                            object
# creator                                        object
# created_t                                       int64
# created_datetime                               object
# last_modified_t                                 int64
# last_modified_datetime                         object
# product_name                                   object
# generic_name                                   object
# quantity                                       object
# packaging                                      object
# packaging_tags                                 object
# brands                                         object
# brands_tags                                    object
# categories                                     object
# categories_tags                                object
# categories_en                                  object
# origins                                        object
# origins_tags                                   object
# manufacturing_places                           object
# manufacturing_places_tags                      object
# labels                                         object
# labels_tags                                    object
# labels_en                                      object
# emb_codes                                      object
# emb_codes_tags                                 object
# first_packaging_code_geo                       object
# cities                                        float64
# cities_tags                                    object
# purchase_places                                object
# stores                                         object
# countries                                      object
# countries_tags                                 object
# countries_en                                   object
# ingredients_text                               object
# allergens                                      object
# allergens_en                                  float64
# traces                                         object
# traces_tags                                    object
# traces_en                                      object
# serving_size                                   object
# serving_quantity                              float64
# no_nutriments                                 float64
# additives_n                                   float64
# additives                                     float64
# additives_tags                                 object
# additives_en                                   object
# ingredients_from_palm_oil_n                   float64
# ingredients_from_palm_oil                     float64
# ingredients_from_palm_oil_tags                 object
# ingredients_that_may_be_from_palm_oil_n       float64
# ingredients_that_may_be_from_palm_oil         float64
# ingredients_that_may_be_from_palm_oil_tags     object
# nutriscore_score                              float64
# nutriscore_grade                               object
# nova_group                                    float64
# pnns_groups_1                                  object
# pnns_groups_2                                  object
# states                                         object
# states_tags                                    object
# states_en                                      object
# brand_owner                                    object
# main_category                                  object
# main_category_en                               object
# image_url                                      object
# image_small_url                                object
# image_ingredients_url                          object
# image_ingredients_small_url                    object
# image_nutrition_url                            object
# image_nutrition_small_url                      object
# energy-kj_100g                                float64
# energy-kcal_100g                              float64
# energy_100g                                   float64
# energy-from-fat_100g                          float64
# fat_100g                                      float64
# saturated-fat_100g                            float64
# -butyric-acid_100g                            float64
# -caproic-acid_100g                            float64
# -caprylic-acid_100g                           float64
# -capric-acid_100g                             float64
# -lauric-acid_100g                             float64
# -myristic-acid_100g                           float64
# -palmitic-acid_100g                           float64
# -stearic-acid_100g                            float64
# -arachidic-acid_100g                          float64
# -behenic-acid_100g                            float64
# -lignoceric-acid_100g                         float64
# -cerotic-acid_100g                            float64
# -montanic-acid_100g                           float64
# -melissic-acid_100g                           float64
# monounsaturated-fat_100g                      float64
# polyunsaturated-fat_100g                      float64
# omega-3-fat_100g                              float64
# -alpha-linolenic-acid_100g                    float64
# -eicosapentaenoic-acid_100g                   float64
# -docosahexaenoic-acid_100g                    float64
# omega-6-fat_100g                              float64
# -linoleic-acid_100g                           float64
# -arachidonic-acid_100g                        float64
# -gamma-linolenic-acid_100g                    float64
# -dihomo-gamma-linolenic-acid_100g             float64
# omega-9-fat_100g                              float64
# -oleic-acid_100g                              float64
# -elaidic-acid_100g                            float64
# -gondoic-acid_100g                            float64
# -mead-acid_100g                               float64
# -erucic-acid_100g                             float64
# -nervonic-acid_100g                           float64
# trans-fat_100g                                float64
# cholesterol_100g                              float64
# carbohydrates_100g                            float64
# sugars_100g                                   float64
# -sucrose_100g                                 float64
# -glucose_100g                                 float64
# -fructose_100g                                float64
# -lactose_100g                                 float64
# -maltose_100g                                 float64
# -maltodextrins_100g                           float64
# starch_100g                                   float64
# polyols_100g                                  float64
# fiber_100g                                    float64
# -soluble-fiber_100g                           float64
# -insoluble-fiber_100g                         float64
# proteins_100g                                 float64
# casein_100g                                   float64
# serum-proteins_100g                           float64
# nucleotides_100g                              float64
# salt_100g                                     float64
# sodium_100g                                   float64
# alcohol_100g                                  float64
# vitamin-a_100g                                float64
# beta-carotene_100g                            float64
# vitamin-d_100g                                float64
# vitamin-e_100g                                float64
# vitamin-k_100g                                float64
# vitamin-c_100g                                float64
# vitamin-b1_100g                               float64
# vitamin-b2_100g                               float64
# vitamin-pp_100g                               float64
# vitamin-b6_100g                               float64
# vitamin-b9_100g                               float64
# folates_100g                                  float64
# vitamin-b12_100g                              float64
# biotin_100g                                   float64
# pantothenic-acid_100g                         float64
# silica_100g                                   float64
# bicarbonate_100g                              float64
# potassium_100g                                float64
# chloride_100g                                 float64
# calcium_100g                                  float64
# phosphorus_100g                               float64
# iron_100g                                     float64
# magnesium_100g                                float64
# zinc_100g                                     float64
# copper_100g                                   float64
# manganese_100g                                float64
# fluoride_100g                                 float64
# selenium_100g                                 float64
# chromium_100g                                 float64
# molybdenum_100g                               float64
# iodine_100g                                   float64
# caffeine_100g                                 float64
# taurine_100g                                  float64
# ph_100g                                       float64
# fruits-vegetables-nuts_100g                   float64
# fruits-vegetables-nuts-dried_100g             float64
# fruits-vegetables-nuts-estimate_100g          float64
# collagen-meat-protein-ratio_100g              float64
# cocoa_100g                                    float64
# chlorophyl_100g                               float64
# carbon-footprint_100g                         float64
# carbon-footprint-from-meat-or-fish_100g       float64
# nutrition-score-fr_100g                       float64
# nutrition-score-uk_100g                       float64
# glycemic-index_100g                           float64
# water-hardness_100g                           float64
# choline_100g                                  float64
# phylloquinone_100g                            float64
# beta-glucan_100g                              float64
# inositol_100g                                 float64
# carnitine_100g                                float64
# dtype: object

# %%
def missing_value(data):
    return data.isna().sum().sum(), data.isna().sum().sort_values()

missing_value(openfoodfacts)
# Out:
# (4365327,
#  code                                              0
#  url                                               0
#  creator                                           0
#  created_t                                         0
#  created_datetime                                  0
#  last_modified_t                                   0
#  last_modified_datetime                            0
#  pnns_groups_2                                     0
#  states                                            0
#  states_tags                                       0
#  states_en                                         0
#  pnns_groups_1                                    53
#  countries                                        64
#  countries_tags                                   64
#  countries_en                                     64
#  product_name                                    701
#  energy_100g                                    2203
#  carbohydrates_100g                             2224
#  fat_100g                                       2242
#  proteins_100g                                  2250
#  energy-kcal_100g                               2360
#  salt_100g                                      2494
#  sodium_100g                                    2494
#  sugars_100g                                    3869
#  additives_n                                    4942
#  ingredients_from_palm_oil_n                    4942
#  ingredients_that_may_be_from_palm_oil_n        4942
#  ingredients_text                               4942
#  serving_quantity                               5585
#  serving_size                                   5586
#  saturated-fat_100g                             6182
#  nova_group                                     6855
#  categories_en                                  6907
#  main_category_en                               6907
#  categories                                     6907
#  main_category                                  6907
#  categories_tags                                6907
#  brand_owner                                    8490
#  fiber_100g                                    10116
#  cholesterol_100g                              10659
#  trans-fat_100g                                10869
#  iron_100g                                     11027
#  calcium_100g                                  11114
#  nutriscore_grade                              12122
#  nutriscore_score                              12122
#  nutrition-score-fr_100g                       12122
#  brands_tags                                   13581
#  brands                                        13581
#  vitamin-c_100g                                13730
#  additives_tags                                13812
#  additives_en                                  13812
#  vitamin-a_100g                                14206
#  potassium_100g                                25957
#  image_url                                     26148
#  image_small_url                               26148
#  allergens                                     26506
#  polyunsaturated-fat_100g                      28217
#  monounsaturated-fat_100g                      28219
#  image_nutrition_small_url                     28469
#  image_nutrition_url                           28469
#  image_ingredients_url                         28723
#  image_ingredients_small_url                   28723
#  stores                                        29306
#  labels_en                                     29901
#  labels_tags                                   29901
#  labels                                        29901
#  vitamin-b1_100g                               30115
#  vitamin-pp_100g                               30255
#  quantity                                      30261
#  vitamin-b2_100g                               30300
#  ingredients_that_may_be_from_palm_oil_tags    30809
#  vitamin-b6_100g                               31084
#  phosphorus_100g                               31280
#  folates_100g                                  31293
#  packaging_tags                                31307
#  packaging                                     31307
#  vitamin-b12_100g                              31378
#  magnesium_100g                                31385
#  zinc_100g                                     31471
#  vitamin-d_100g                                31588
#  purchase_places                               31647
#  vitamin-b9_100g                               31661
#  generic_name                                  31838
#  traces_tags                                   31881
#  traces_en                                     31881
#  manufacturing_places_tags                     31898
#  manufacturing_places                          31898
#  -soluble-fiber_100g                           31953
#  traces                                        31975
#  pantothenic-acid_100g                         31979
#  copper_100g                                   31981
#  manganese_100g                                32014
#  energy-kj_100g                                32083
#  origins                                       32085
#  origins_tags                                  32086
#  -insoluble-fiber_100g                         32089
#  polyols_100g                                  32169
#  phylloquinone_100g                            32178
#  alcohol_100g                                  32195
#  emb_codes                                     32196
#  emb_codes_tags                                32196
#  selenium_100g                                 32202
#  iodine_100g                                   32211
#  energy-from-fat_100g                          32220
#  ingredients_from_palm_oil_tags                32251
#  vitamin-k_100g                                32255
#  cities_tags                                   32270
#  first_packaging_code_geo                      32271
#  fruits-vegetables-nuts-estimate_100g          32279
#  carbon-footprint-from-meat-or-fish_100g       32283
#  starch_100g                                   32289
#  biotin_100g                                   32291
#  cocoa_100g                                    32296
#  caffeine_100g                                 32297
#  molybdenum_100g                               32297
#  fruits-vegetables-nuts_100g                   32300
#  vitamin-e_100g                                32301
#  chromium_100g                                 32301
#  omega-3-fat_100g                              32304
#  -alpha-linolenic-acid_100g                    32306
#  omega-6-fat_100g                              32307
#  -behenic-acid_100g                            32308
#  bicarbonate_100g                              32308
#  -arachidonic-acid_100g                        32308
#  -arachidic-acid_100g                          32308
#  chlorophyl_100g                               32309
#  nutrition-score-uk_100g                       32309
#  glycemic-index_100g                           32309
#  chloride_100g                                 32309
#  silica_100g                                   32309
#  ph_100g                                       32309
#  water-hardness_100g                           32309
#  choline_100g                                  32309
#  taurine_100g                                  32309
#  collagen-meat-protein-ratio_100g              32309
#  beta-glucan_100g                              32309
#  fluoride_100g                                 32309
#  carbon-footprint_100g                         32309
#  fruits-vegetables-nuts-dried_100g             32309
#  ingredients_that_may_be_from_palm_oil         32309
#  nucleotides_100g                              32309
#  inositol_100g                                 32309
#  -melissic-acid_100g                           32309
#  -montanic-acid_100g                           32309
#  -cerotic-acid_100g                            32309
#  -lignoceric-acid_100g                         32309
#  -stearic-acid_100g                            32309
#  -palmitic-acid_100g                           32309
#  -myristic-acid_100g                           32309
#  -lauric-acid_100g                             32309
#  -capric-acid_100g                             32309
#  -caprylic-acid_100g                           32309
#  -caproic-acid_100g                            32309
#  -butyric-acid_100g                            32309
#  allergens_en                                  32309
#  no_nutriments                                 32309
#  additives                                     32309
#  ingredients_from_palm_oil                     32309
#  cities                                        32309
#  beta-carotene_100g                            32309
#  -eicosapentaenoic-acid_100g                   32309
#  -linoleic-acid_100g                           32309
#  serum-proteins_100g                           32309
#  casein_100g                                   32309
#  -maltodextrins_100g                           32309
#  -maltose_100g                                 32309
#  -lactose_100g                                 32309
#  -fructose_100g                                32309
#  -glucose_100g                                 32309
#  -sucrose_100g                                 32309
#  -nervonic-acid_100g                           32309
#  -erucic-acid_100g                             32309
#  -mead-acid_100g                               32309
#  -gondoic-acid_100g                            32309
#  -elaidic-acid_100g                            32309
#  -oleic-acid_100g                              32309
#  omega-9-fat_100g                              32309
#  -dihomo-gamma-linolenic-acid_100g             32309
#  -gamma-linolenic-acid_100g                    32309
#  -docosahexaenoic-acid_100g                    32309
#  carnitine_100g                                32309
#  dtype: int64)

# %% [markdown]
# Notons que plusieurs variables sont totalement vides, sans aucune valeur ni modalité. Dans l'immédiat la variable 'states' apporte plus de précisions, en quelque sorte un "état de santé" des données du fichier.

# %%
states_tags = {}
for i in openfoodfacts.index:
    tags = str(openfoodfacts.at[i, 'states']).split(",")
    for tag in tags:
        if tag in states_tags:
            states_tags[tag] += 1
        else:
            states_tags[tag] = 1
            
sorted_states_tags = sorted(states_tags, key=states_tags.get, reverse=True)

for tag in sorted_states_tags:
    print(f"{tag}: {states_tags[tag]}")
# Out:
#  en:packaging-code-to-be-completed: 32194
# en:to-be-completed: 31762
#  en:product-name-completed: 31607
#  en:characteristics-to-be-completed: 31494
#  en:expiration-date-to-be-completed: 31370
#  en:packaging-to-be-completed: 31307
#  en:nutrition-facts-completed: 30798
#  en:quantity-to-be-completed: 30260
#  en:ingredients-completed: 27332
#  en:categories-completed: 25401
#  en:photos-to-be-uploaded: 24754
#  en:brands-completed: 18727
#  en:brands-to-be-completed: 13581
#  en:photos-uploaded: 7555
#  en:categories-to-be-completed: 6907
#  en:photos-to-be-validated: 6132
#  en:ingredients-to-be-completed: 4977
#  en:quantity-completed: 2048
#  en:nutrition-facts-to-be-completed: 1511
#  en:photos-validated: 1423
#  en:packaging-completed: 1002
#  en:expiration-date-completed: 939
#  en:characteristics-completed: 815
#  en:product-name-to-be-completed: 701
#  en:complete: 542
# en:to-be-checked: 536
#  en:packaging-code-completed: 113
# en:checked: 6
# en:empty: 5
#  en:to-be-completed: 5

# %% [markdown]
# La variable 'states' apporte une information synthétique rapide sur l'état de santé global du jeu de données comme l'atteste l'affichage ci-dessus.\
# Elle peut être utilisée pour des opérations de resctriction, afin d'obtenir la qualité des données qui nous intéresse en fonction des objectifs définis.

# %%
def restriction_state(data, state_carac):
    data = data[data['states'].str.contains(state_carac)]
    return data

restriction_state(openfoodfacts, 'en:product-name-completed')
# Out:
#                        code  \
# 0                        17
# 1                        31
# 2        000000000003327986
# 4      00000000001111111111
# 5                       123
# ...                     ...
# 32303           20138137263
# 32304           20138138093
# 32305           20138138109
# 32306           20138150668
# 32307           20138153058
#
#                                                      url  \
# 0      http://world-en.openfoodfacts.org/product/0000...
# 1      http://world-en.openfoodfacts.org/product/0000...
# 2      http://world-en.openfoodfacts.org/product/0000...
# 4      http://world-en.openfoodfacts.org/product/0000...
# 5      http://world-en.openfoodfacts.org/product/0000...
# ...                                                  ...
# 32303  http://world-en.openfoodfacts.org/product/0020...
# 32304  http://world-en.openfoodfacts.org/product/0020...
# 32305  http://world-en.openfoodfacts.org/product/0020...
# 32306  http://world-en.openfoodfacts.org/product/0020...
# 32307  http://world-en.openfoodfacts.org/product/0020...
#
#                           creator   created_t      created_datetime  \
# 0                         kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                        isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                         kiliweb  1574175736  2019-11-19T15:02:16Z
# 4      openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
# 5                         kiliweb  1535737982  2018-08-31T17:53:02Z
# ...                           ...         ...                   ...
# 32303             usda-ndb-import  1489135968  2017-03-10T08:52:48Z
# 32304           org-database-usda  1587667197  2020-04-23T18:39:57Z
# 32305           org-database-usda  1587667205  2020-04-23T18:40:05Z
# 32306             usda-ndb-import  1489093992  2017-03-09T21:13:12Z
# 32307                     kiliweb  1588521721  2020-05-03T16:02:01Z
#
#        last_modified_t last_modified_datetime  \
# 0           1561463718   2019-06-25T11:55:18Z
# 1           1539464817   2018-10-13T21:06:57Z
# 2           1574175737   2019-11-19T15:02:17Z
# 4           1560020173   2019-06-08T18:56:13Z
# 5           1535737986   2018-08-31T17:53:06Z
# ...                ...                    ...
# 32303       1587627863   2020-04-23T07:44:23Z
# 32304       1587667197   2020-04-23T18:39:57Z
# 32305       1587667206   2020-04-23T18:40:06Z
# 32306       1587593373   2020-04-22T22:09:33Z
# 32307       1588522421   2020-05-03T16:13:41Z
#
#                                      product_name generic_name quantity  ...  \
# 0                                Vitória crackers          NaN      NaN  ...
# 1                                           Cacao          NaN    130 g  ...
# 2                       Filetes de pollo empanado          NaN      NaN  ...
# 4                                         Sfiudwx          NaN    dgesc  ...
# 5                           Sauce Sweety chili 0%          NaN      NaN  ...
# ...                                           ...          ...      ...  ...
# 32303                               Mustard Sauce          NaN      NaN  ...
# 32304                   Mixed berry pepper relish          NaN      NaN  ...
# 32305                         Peach mango chutney          NaN      NaN  ...
# 32306            Roasted Pineapple Habanero Sauce          NaN      NaN  ...
# 32307  Old Fashion Fredericksburg Peach Preserves          NaN    40 oz  ...
#
#       carbon-footprint-from-meat-or-fish_100g nutrition-score-fr_100g  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 4                                         NaN                     NaN
# 5                                         NaN                     NaN
# ...                                       ...                     ...
# 32303                                     NaN                     7.0
# 32304                                     NaN                     6.0
# 32305                                     NaN                     7.0
# 32306                                     NaN                     7.0
# 32307                                     NaN                     NaN
#
#       nutrition-score-uk_100g glycemic-index_100g water-hardness_100g  \
# 0                         NaN                 NaN                 NaN
# 1                         NaN                 NaN                 NaN
# 2                         NaN                 NaN                 NaN
# 4                         NaN                 NaN                 NaN
# 5                         NaN                 NaN                 NaN
# ...                       ...                 ...                 ...
# 32303                     NaN                 NaN                 NaN
# 32304                     NaN                 NaN                 NaN
# 32305                     NaN                 NaN                 NaN
# 32306                     NaN                 NaN                 NaN
# 32307                     NaN                 NaN                 NaN
#
#       choline_100g phylloquinone_100g beta-glucan_100g inositol_100g  \
# 0              NaN                NaN              NaN           NaN
# 1              NaN                NaN              NaN           NaN
# 2              NaN                NaN              NaN           NaN
# 4              NaN                NaN              NaN           NaN
# 5              NaN                NaN              NaN           NaN
# ...            ...                ...              ...           ...
# 32303          NaN                NaN              NaN           NaN
# 32304          NaN                NaN              NaN           NaN
# 32305          NaN                NaN              NaN           NaN
# 32306          NaN                NaN              NaN           NaN
# 32307          NaN                NaN              NaN           NaN
#
#       carnitine_100g
# 0                NaN
# 1                NaN
# 2                NaN
# 4                NaN
# 5                NaN
# ...              ...
# 32303            NaN
# 32304            NaN
# 32305            NaN
# 32306            NaN
# 32307            NaN
#
# [31607 rows x 181 columns]

# %% [markdown]
# Un risque d'erreur dans la variable 'states' est possible, un test complémentaire de modalité manquante est recommandé.

# %%
openfoodfacts.dropna(subset=["product_name"], axis=0, how='any').shape
# Out:
# (31608, 181)

# %% [markdown]
# Résultat concluant sur l'utilisation de la variable 'states'…

# %%
openfoodfacts = restriction_state(openfoodfacts, 'en:product-name-completed')
openfoodfacts.shape
# Out:
# (31607, 181)

# %%
print(openfoodfacts[openfoodfacts['nutriscore_score'].isna()].shape[0])
print(openfoodfacts[openfoodfacts['nutriscore_grade'].isna()].shape[0])
print(openfoodfacts[openfoodfacts['nutrition-score-uk_100g'].isna()].shape[0])
# Out:
# 11441
# 11441
# 31607

# %% [markdown]
# Notons un point positif concernant les données propres au Nutri-score, les deux variables 'nutriscore_score' et 'nutriscore_grade' semblent avoir le même degré de complétude. Deuxièmement la variable 'nutrition-score-uk_100g' ressort comme étant beaucoup moins qualitative.
#
# Rappelons que dans le contexte métier de l'application, une observation sans désignation produit n'est pas qualitative, mais une observation sans Nutri-score (ou Nutri-grade) l'est encore moins. **Une restriction complémentaire peut-être opérée en ne conservant que les observations avec l'info du Nutri-score.**

# %%
openfoodfacts = openfoodfacts[openfoodfacts['nutriscore_score'].notna()]
openfoodfacts.shape
# Out:
# (20166, 181)

# %%
openfoodfacts = restriction_state(openfoodfacts, 'en:nutrition-facts-completed')
openfoodfacts.shape
# Out:
# (20166, 181)

# %% [markdown]
# La restiction des données via 'en:nutrition-facts-completed' (from variable 'states'), ne permet pas d'optimiser plus les observations.

# %% [markdown]
# ### Nettoyage et pré-traitement des variables
# Recherche de variables en doublon, de valeurs manquantes en forte quantité, etc… ayant pour effet d'alourdir inutilement l'échantillon.

# %%
def missing_value_clean(data):
    sample_data_part = (data.count()/data.shape[0]*100).round(0)
    sample_data_part.sort_values(ascending=False, inplace=True)
    return sample_data_part

missing_value_clean(openfoodfacts)
# Out:
# code                                          100.0
# main_category_en                              100.0
# pnns_groups_1                                 100.0
# pnns_groups_2                                 100.0
# states                                        100.0
# states_tags                                   100.0
# states_en                                     100.0
# main_category                                 100.0
# energy_100g                                   100.0
# proteins_100g                                 100.0
# fat_100g                                      100.0
# saturated-fat_100g                            100.0
# carbohydrates_100g                            100.0
# sugars_100g                                   100.0
# sodium_100g                                   100.0
# salt_100g                                     100.0
# nutriscore_grade                              100.0
# nutriscore_score                              100.0
# categories                                    100.0
# categories_en                                 100.0
# url                                           100.0
# creator                                       100.0
# created_t                                     100.0
# created_datetime                              100.0
# last_modified_t                               100.0
# last_modified_datetime                        100.0
# nutrition-score-fr_100g                       100.0
# countries_en                                  100.0
# countries_tags                                100.0
# product_name                                  100.0
# categories_tags                               100.0
# countries                                     100.0
# energy-kcal_100g                               99.0
# ingredients_text                               97.0
# additives_n                                    97.0
# ingredients_that_may_be_from_palm_oil_n        97.0
# ingredients_from_palm_oil_n                    97.0
# serving_size                                   96.0
# serving_quantity                               96.0
# fiber_100g                                     94.0
# nova_group                                     94.0
# brand_owner                                    92.0
# cholesterol_100g                               92.0
# iron_100g                                      91.0
# trans-fat_100g                                 91.0
# calcium_100g                                   90.0
# vitamin-c_100g                                 78.0
# vitamin-a_100g                                 77.0
# additives_tags                                 67.0
# additives_en                                   67.0
# brands                                         59.0
# brands_tags                                    59.0
# potassium_100g                                 27.0
# allergens                                      26.0
# polyunsaturated-fat_100g                       17.0
# monounsaturated-fat_100g                       17.0
# stores                                         10.0
# image_url                                      10.0
# image_small_url                                10.0
# vitamin-b1_100g                                 9.0
# vitamin-b2_100g                                 8.0
# vitamin-pp_100g                                 8.0
# image_nutrition_small_url                       7.0
# labels                                          7.0
# labels_en                                       7.0
# labels_tags                                     7.0
# image_nutrition_url                             7.0
# image_ingredients_small_url                     7.0
# image_ingredients_url                           7.0
# quantity                                        5.0
# ingredients_that_may_be_from_palm_oil_tags      5.0
# vitamin-b6_100g                                 4.0
# phosphorus_100g                                 4.0
# magnesium_100g                                  4.0
# folates_100g                                    4.0
# vitamin-b12_100g                                3.0
# zinc_100g                                       3.0
# packaging_tags                                  3.0
# vitamin-b9_100g                                 3.0
# vitamin-d_100g                                  3.0
# packaging                                       3.0
# generic_name                                    2.0
# -soluble-fiber_100g                             2.0
# purchase_places                                 2.0
# manufacturing_places_tags                       1.0
# traces_tags                                     1.0
# traces                                          1.0
# -insoluble-fiber_100g                           1.0
# origins_tags                                    1.0
# energy-kj_100g                                  1.0
# manufacturing_places                            1.0
# manganese_100g                                  1.0
# pantothenic-acid_100g                           1.0
# origins                                         1.0
# copper_100g                                     1.0
# traces_en                                       1.0
# water-hardness_100g                             0.0
# carbon-footprint-from-meat-or-fish_100g         0.0
# nutrition-score-uk_100g                         0.0
# glycemic-index_100g                             0.0
# beta-glucan_100g                                0.0
# choline_100g                                    0.0
# phylloquinone_100g                              0.0
# fluoride_100g                                   0.0
# ingredients_from_palm_oil                       0.0
# ingredients_from_palm_oil_tags                  0.0
# collagen-meat-protein-ratio_100g                0.0
# no_nutriments                                   0.0
# selenium_100g                                   0.0
# fruits-vegetables-nuts-dried_100g               0.0
# cocoa_100g                                      0.0
# chlorophyl_100g                                 0.0
# carbon-footprint_100g                           0.0
# emb_codes                                       0.0
# emb_codes_tags                                  0.0
# first_packaging_code_geo                        0.0
# cities                                          0.0
# cities_tags                                     0.0
# ingredients_that_may_be_from_palm_oil           0.0
# additives                                       0.0
# ph_100g                                         0.0
# taurine_100g                                    0.0
# caffeine_100g                                   0.0
# allergens_en                                    0.0
# iodine_100g                                     0.0
# molybdenum_100g                                 0.0
# fruits-vegetables-nuts-estimate_100g            0.0
# chromium_100g                                   0.0
# fruits-vegetables-nuts_100g                     0.0
# casein_100g                                     0.0
# chloride_100g                                   0.0
# vitamin-e_100g                                  0.0
# -arachidonic-acid_100g                          0.0
# -gamma-linolenic-acid_100g                      0.0
# -dihomo-gamma-linolenic-acid_100g               0.0
# omega-9-fat_100g                                0.0
# -oleic-acid_100g                                0.0
# -elaidic-acid_100g                              0.0
# -gondoic-acid_100g                              0.0
# -mead-acid_100g                                 0.0
# -erucic-acid_100g                               0.0
# -nervonic-acid_100g                             0.0
# beta-carotene_100g                              0.0
# omega-6-fat_100g                                0.0
# alcohol_100g                                    0.0
# -sucrose_100g                                   0.0
# -glucose_100g                                   0.0
# -fructose_100g                                  0.0
# -lactose_100g                                   0.0
# -maltose_100g                                   0.0
# -maltodextrins_100g                             0.0
# starch_100g                                     0.0
# polyols_100g                                    0.0
# nucleotides_100g                                0.0
# -linoleic-acid_100g                             0.0
# -docosahexaenoic-acid_100g                      0.0
# bicarbonate_100g                                0.0
# -palmitic-acid_100g                             0.0
# silica_100g                                     0.0
# biotin_100g                                     0.0
# serum-proteins_100g                             0.0
# energy-from-fat_100g                            0.0
# -butyric-acid_100g                              0.0
# -caproic-acid_100g                              0.0
# -caprylic-acid_100g                             0.0
# -capric-acid_100g                               0.0
# -lauric-acid_100g                               0.0
# -myristic-acid_100g                             0.0
# -stearic-acid_100g                              0.0
# -eicosapentaenoic-acid_100g                     0.0
# -arachidic-acid_100g                            0.0
# -behenic-acid_100g                              0.0
# -lignoceric-acid_100g                           0.0
# -cerotic-acid_100g                              0.0
# -montanic-acid_100g                             0.0
# -melissic-acid_100g                             0.0
# inositol_100g                                   0.0
# vitamin-k_100g                                  0.0
# omega-3-fat_100g                                0.0
# -alpha-linolenic-acid_100g                      0.0
# carnitine_100g                                  0.0
# dtype: float64

# %% [markdown]
# Le seuil des 50% de données disponibles / variable semble répondre aux besoins essentiels de l'application(fibres, protéines, énergie, acides gras saturés, sucres, sel). **Une première sélection peut-être opérée selon cette condition.**

# %%
openfoodfacts = openfoodfacts.loc[:, missing_value_clean(openfoodfacts) >= 50]
openfoodfacts.shape
# Out:
# (20166, 52)

# %%
def variable_duplicate(data, var1, var2):
    return data[var1].nunique() == data[var2].nunique() 
    
display(variable_duplicate(openfoodfacts, 'states', 'states_tags'))
display(variable_duplicate(openfoodfacts, 'additives_en', 'additives_tags'))
display(variable_duplicate(openfoodfacts, 'countries_en', 'countries_tags'))
display(variable_duplicate(openfoodfacts, 'categories_en', 'categories_tags'))
# Out:
# True
# True
# True
# True

# %%
def variable_duplicate_clean(data):
    data = data.loc[:, ~data.columns.str.contains('_tags', case=False, na=False)]
    return data

openfoodfacts = variable_duplicate_clean(openfoodfacts)
display(openfoodfacts.shape)
display(openfoodfacts.head())
# Out:
# (20166, 47)
#     code                                                url  creator  \
# 13   949  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 21  1281  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 31  1885  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 35  2257  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 59  5005  http://world-en.openfoodfacts.org/product/0000...  kiliweb
#
#      created_t      created_datetime  last_modified_t last_modified_datetime  \
# 13  1523440813  2018-04-11T10:00:13Z       1565268412   2019-08-08T12:46:52Z
# 21  1517830801  2018-02-05T11:40:01Z       1527070794   2018-05-23T10:19:54Z
# 31  1511180337  2017-11-20T12:18:57Z       1518126491   2018-02-08T21:48:11Z
# 35  1520506122  2018-03-08T10:48:42Z       1561463749   2019-06-25T11:55:49Z
# 59  1521663684  2018-03-21T20:21:24Z       1545934272   2018-12-27T18:11:12Z
#
#                       product_name              brands  \
# 13       Salade de carottes râpées                 NaN
# 21              Tarte noix de coco  Crous Resto',Crous
# 31                Compote de poire               Crous
# 35  Salade de macedoine de légumes                 NaN
# 59                       Abondance                 NaN
#
#                                            categories  ... sugars_100g  \
# 13  Plats préparés, Légumes préparés, Carottes râp...  ...         3.9
# 21   Tartes, Tartes sucrées, Tartes à la noix de coco  ...        21.9
# 31  Aliments et boissons à base de végétaux, Alime...  ...        27.0
# 35  Plats préparés, Légumes préparés, Entrées, Ent...  ...         1.0
# 59  Produits laitiers, Produits fermentés, Produit...  ...         0.1
#
#    fiber_100g proteins_100g salt_100g sodium_100g  vitamin-a_100g  \
# 13        NaN           0.9      0.42       0.168             NaN
# 21        4.4           4.6      0.10       0.040             NaN
# 31        3.6           0.6      0.00       0.000             NaN
# 35        NaN           1.9      0.27       0.108             NaN
# 59        NaN          25.0      1.30       0.520             NaN
#
#     vitamin-c_100g calcium_100g  iron_100g  nutrition-score-fr_100g
# 13             NaN          NaN        NaN                      1.0
# 21             NaN          NaN        NaN                     14.0
# 31             NaN          NaN        NaN                     -2.0
# 35             NaN          NaN        NaN                      1.0
# 59             NaN          NaN        NaN                     14.0
#
# [5 rows x 47 columns]

# %% [markdown]
# *Le dédoublonnage des variables réduit l'échantillon à 47 features.*
#
# Arrêtons-nous sur les variables temporelles, sans intérêt majeur semble t-il… Ceci étant, le format n'est pas facilement exploitable, il peut-être pertinent de le modifier pour rendre son usage plus explicite et décider ensuite de la prise en compte ou non pour la suite de l'analyse.

# %%
def time_clean(data):
    for var in data.columns :
        if var[-2:] == "_t":
            data[var] = pd.to_datetime(data[var], unit='s')
        if var[-9:] == "_datetime":
            data[var] = pd.to_datetime(data[var]).dt.strftime('%Y-%m-%d %H:%M%:%S')
    return data
            
openfoodfacts = time_clean(openfoodfacts)
display(openfoodfacts.shape)
display(openfoodfacts.head())
# Out:
# (20166, 47)
#     code                                                url  creator  \
# 13   949  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 21  1281  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 31  1885  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 35  2257  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 59  5005  http://world-en.openfoodfacts.org/product/0000...  kiliweb
#
#              created_t     created_datetime     last_modified_t  \
# 13 2018-04-11 10:00:13  2018-04-11 10:00:13 2019-08-08 12:46:52
# 21 2018-02-05 11:40:01  2018-02-05 11:40:01 2018-05-23 10:19:54
# 31 2017-11-20 12:18:57  2017-11-20 12:18:57 2018-02-08 21:48:11
# 35 2018-03-08 10:48:42  2018-03-08 10:48:42 2019-06-25 11:55:49
# 59 2018-03-21 20:21:24  2018-03-21 20:21:24 2018-12-27 18:11:12
#
#    last_modified_datetime                    product_name              brands  \
# 13    2019-08-08 12:46:52       Salade de carottes râpées                 NaN
# 21    2018-05-23 10:19:54              Tarte noix de coco  Crous Resto',Crous
# 31    2018-02-08 21:48:11                Compote de poire               Crous
# 35    2019-06-25 11:55:49  Salade de macedoine de légumes                 NaN
# 59    2018-12-27 18:11:12                       Abondance                 NaN
#
#                                            categories  ... sugars_100g  \
# 13  Plats préparés, Légumes préparés, Carottes râp...  ...         3.9
# 21   Tartes, Tartes sucrées, Tartes à la noix de coco  ...        21.9
# 31  Aliments et boissons à base de végétaux, Alime...  ...        27.0
# 35  Plats préparés, Légumes préparés, Entrées, Ent...  ...         1.0
# 59  Produits laitiers, Produits fermentés, Produit...  ...         0.1
#
#    fiber_100g proteins_100g salt_100g sodium_100g  vitamin-a_100g  \
# 13        NaN           0.9      0.42       0.168             NaN
# 21        4.4           4.6      0.10       0.040             NaN
# 31        3.6           0.6      0.00       0.000             NaN
# 35        NaN           1.9      0.27       0.108             NaN
# 59        NaN          25.0      1.30       0.520             NaN
#
#     vitamin-c_100g calcium_100g  iron_100g  nutrition-score-fr_100g
# 13             NaN          NaN        NaN                      1.0
# 21             NaN          NaN        NaN                     14.0
# 31             NaN          NaN        NaN                     -2.0
# 35             NaN          NaN        NaN                      1.0
# 59             NaN          NaN        NaN                     14.0
#
# [5 rows x 47 columns]

# %% [markdown]
# Notons une similitude dans les variables 'created_t' et	'created_datetime', ainsi que 'last_modified_t'	et 'last_modified_datetime'.
#
# _Vérifions le à l'aide de la fonction variable_duplicate()…_

# %%
display(variable_duplicate(openfoodfacts, 'created_t', 'created_datetime'))
display(variable_duplicate(openfoodfacts, 'last_modified_t', 'last_modified_datetime'))
# Out:
# True
# True

# %%
openfoodfacts.drop(columns=['created_datetime', 'last_modified_datetime'], inplace=True)

# %%
openfoodfacts.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'last_modified_t',
#        'product_name', 'brands', 'categories', 'categories_en', 'countries',
#        'countries_en', 'ingredients_text', 'serving_size', 'serving_quantity',
#        'additives_n', 'additives_en', 'ingredients_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil_n', 'nutriscore_score',
#        'nutriscore_grade', 'nova_group', 'pnns_groups_1', 'pnns_groups_2',
#        'states', 'states_en', 'brand_owner', 'main_category',
#        'main_category_en', 'energy-kcal_100g', 'energy_100g', 'fat_100g',
#        'saturated-fat_100g', 'trans-fat_100g', 'cholesterol_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g', 'vitamin-a_100g', 'vitamin-c_100g',
#        'calcium_100g', 'iron_100g', 'nutrition-score-fr_100g'],
#       dtype='object')

# %% [markdown]
# Les variables de l'échantillon ne sont pas toutes utiles pour l'application choisie, mais les données sont disponibles pour la plupart (au minimum 50% valeurs disponibles pour chaque variable).
#
# Des variables non indispensables au bon fonctionnement de l'application souhaitée. Malgré tout ces variables informatives sont pour le moment conservées **à l'exception que quelques colonnes qui semblent être présentées en doublon, vérifions ces cas de duplications possibles.**

# %%
def display_duplicate_var(data, var1, var2):
    return data[var1].unique(), data[var2].unique()

# %% [markdown]
# `energy-kcal_100g / energy_100g` (0.239kcal = 1kJ ou 4,184kJ = 1kcal)\
# Il existe deux unités pour définir l’apport énergétique d’un aliment, la calorie (en Kcal) et le
# Joule (en Kj). La quantité d’énergie est mesurée en Joule, ou J (et donc 1 kiloJoule, noté kJ, vaut 1000 Joules).

# %%
display(openfoodfacts['energy-kcal_100g']*4,184)
display(openfoodfacts['energy_100g'])
# Out:
# 13        128.0
# 21       1524.0
# 31        628.0
# 35        572.0
# 59       1588.0
#           ...
# 32302     700.0
# 32303     900.0
# 32304     400.0
# 32305     500.0
# 32306     500.0
# Name: energy-kcal_100g, Length: 20166, dtype: float64
# 184
# 13        134.0
# 21       1594.0
# 31        657.0
# 35        598.0
# 59       1661.0
#           ...
# 32302     732.0
# 32303     941.0
# 32304     418.0
# 32305     523.0
# 32306     523.0
# Name: energy_100g, Length: 20166, dtype: float64

# %% [markdown]
# Notons que ces deux variables, après vérification de nos hypothèses et intuitions de départ, sont bien similaires.\
# **La variable 'energy-kcal_100g' sera donc supprimée.**

# %%
openfoodfacts.drop(columns='energy-kcal_100g', inplace=True)

# %% [markdown]
# `nutriscore_score / nutrition-score-fr_100g`

# %%
display_duplicate_var(openfoodfacts, 'nutriscore_score', 'nutrition-score-fr_100g')
# Out:
# (array([  1.,  14.,  -2.,   4.,   0.,  -4.,  15.,  17.,  21.,   2.,   3.,
#          29.,   6.,  22.,   9.,   7.,   5.,  28.,  24.,  13.,  12.,  16.,
#          18.,  26.,  19.,  11.,  36.,  -3.,  20.,  27.,  10.,  23.,  25.,
#          -7.,  -1.,  -5.,  -8.,  -6.,  -9., -11.,   8.,  30., -10., -13.,
#         -12., -14.,  33.,  31.,  34.]),
#  array([  1.,  14.,  -2.,   4.,   0.,  -4.,  15.,  17.,  21.,   2.,   3.,
#          29.,   6.,  22.,   9.,   7.,   5.,  28.,  24.,  13.,  12.,  16.,
#          18.,  26.,  19.,  11.,  36.,  -3.,  20.,  27.,  10.,  23.,  25.,
#          -7.,  -1.,  -5.,  -8.,  -6.,  -9., -11.,   8.,  30., -10., -13.,
#         -12., -14.,  33.,  31.,  34.]))

# %%
openfoodfacts.drop(columns='nutriscore_score', inplace=True)

# %% [markdown]
# `categories / categories_en`

# %%
display_duplicate_var(openfoodfacts, 'categories', 'categories_en')
# Out:
# (array(['Plats préparés, Légumes préparés, Carottes râpées, Carottes râpées assaisonnées',
#         'Tartes, Tartes sucrées, Tartes à la noix de coco',
#         "Aliments et boissons à base de végétaux, Aliments d'origine végétale, Desserts, Aliments à base de fruits et de légumes, Fruits et produits dérivés, Compotes, Compotes de poire",
#         ..., 'Meals, Prepared vegetables, Cooked vegetables',
#         'Groceries, Sauces, Pestos, Green pestos',
#         'Alimentos y bebidas de origen vegetal, Alimentos de origen vegetal, Frutas y verduras y sus productos, Frutas y sus productos, Frutas, Cítricos, Naranjas'],
#        dtype=object),
#  array(['Meals,Prepared vegetables,Grated carrots,Seasoned shredded carrots',
#         'Pies,Sweet pies,Coconut pies',
#         'Plant-based foods and beverages,Plant-based foods,Desserts,Fruits and vegetables based foods,Fruits based foods,Compotes,Pear compotes',
#         ..., 'Dried products',
#         'Meals,Prepared vegetables,Cooked vegetables',
#         'Plant-based foods and beverages,Plant-based foods,Fruits and vegetables based foods,Fruits based foods,Fruits,Citrus,Oranges'],
#        dtype=object))

# %% [markdown]
# Notons une similitude des modalités, des différences de traduction sont détectées, le dédoublonnage est donc recommandé.

# %%
openfoodfacts.drop(columns='categories_en', inplace=True)

# %% [markdown]
# `countries / countries_en`

# %%
display_duplicate_var(openfoodfacts, 'countries', 'countries_en')
# Out:
# (array(['France', 'en:fr', 'United States', 'Canada', 'en:be',
#         'France, États-Unis', 'Deutschland', 'en:france', 'United Kingdom',
#         'en:DE', 'en:Italy', 'Belgium', 'en:spain', 'España', 'Spain',
#         'en:es', 'France, United States', 'Portugal', 'en:de', 'México',
#         'en:France', 'France, United Kingdom', 'France, Royaume-Uni',
#         'France,United Kingdom', 'Belgique, France, Pays-Bas, Royaume-Uni',
#         'Royaume-Uni', 'États-Unis, en:france', 'France,Royaume-Uni',
#         'en:GB', 'en:Germany', 'France,France', 'en:FR',
#         'en:fr, United States', 'Spain,en:switzerland', nan, 'en:gb',
#         'Royaume-Uni,en:united-kingdom', 'en:United Kingdom',
#         'Alemania, Spain', 'Royaume-Uni, en:france', 'en:United States',
#         'États-Unis,en:united-states', 'us', 'France,Spain,en:spain',
#         'en:france, United States', 'en:UK',
#         'Frankreich, Deutschland, en:at', 'Mexico,United States',
#         'en:Australia', 'Australia', 'États-Unis',
#         'France,Switzerland, United States',
#         'Francia  Spain, United States',
#         'Canada, Switzerland, United States', 'France,Thailand',
#         'United States,en:united-states', 'Italia',
#         'Vereinigte Staaten von Amerika, en:de', 'en:pf, United States',
#         'United Kingdom, United States', 'Egypt, United States', 'en:us',
#         'en:Belgium, United States', 'en:spain, United States', 'Hrvatska',
#         'Canada, France', 'united-states', 'en:US', 'France,United States',
#         'France,États-Unis', 'México, United States',
#         'Estados Unidos, Spain', 'France,États-Unis,en:france', 'Haiti',
#         'México, Estados Unidos', 'en:Singapore',
#         'France,United States, Switzerland', 'en:au',
#         'Australië,België,Frankrijk,Duitsland,Zwitserland', 'Suisse',
#         'Espagne, en:be', 'España,en:spain', 'en:BE', 'Belgique, France',
#         'Francia', 'Allemagne', 'Frankreich, en:de', 'Francia,Suiza',
#         'Royaume-Uni,France', '澳大利亚, 法国, 新西兰', 'en:French Polynesia',
#         'Australie, États-Unis', 'Francia, Spain', 'Mexico, United States',
#         'Saudi-Arabien', 'Saudi Arabia', 'Émirats arabes unis',
#         'Schweiz,Schweiz, United States', 'en:United Arab Emirates',
#         'en:AE', 'Colombia', 'Francia,España', 'en:Switzerland',
#         'Vereinigte Staaten von Amerika',
#         'France,République tchèque, United States',
#         'Francia, United States', 'فرنسا, العراق, United States',
#         'France,New Caledonia', 'en:Sweden', 'México,Estados Unidos',
#         'España,Estados Unidos', 'en:Saudi Arabia, United States',
#         'Singapore', 'Germany', 'Australia, France, Sweden, United States',
#         'Sverige, USA', 'Austria, Sweden, United States, Germany',
#         'Canada,France', 'en:FR, United States', 'Estados Unidos',
#         'Espagne', 'en:Canada', 'Vietnam', 'Martinique, u.s.a',
#         'France, Royaume-Uni, United States',
#         'Francia,México,Estados Unidos', 'France,Mexico, United States',
#         'France,Switzerland', 'Francia, Suiza, Spain',
#         'France, Suisse, Royaume-Uni',
#         'France,Polynésie française,États-Unis',
#         'France,Mexique,États-Unis', 'Francia, España',
#         'Frankreich, en:ch', 'France,Allemagne', 'France,en:france',
#         'en:es, United States', 'Mexique, en:france', 'France,Espagne',
#         'Australia, New Zealand, Singapore, Thailand, United States',
#         'en:ca', 'Reino Unido', 'France,Polynésie française',
#         'France, Allemagne', 'France, Germany',
#         'Puerto Rico, United States', 'United Kingdom,en:united-kingdom',
#         'Francia,España,Estados Unidos', 'India,España,Estados Unidos',
#         'en:Costa Rica', 'Colombia, Spain',
#         'en:French Polynesia, United States',
#         'België,Verenigde Staten van Amerika', 'Lebanon,United States',
#         'France,French Polynesia', 'Canada, United States',
#         'United Arab Emirates, United States',
#         'France, Nouvelle-Calédonie',
#         'France, Nouvelle-Calédonie, United States',
#         'Polynésie française, United States',
#         'Frankreich, en:de, United States', 'en:nc, United States',
#         'France,Thaïlande', 'Mexico', 'France, Mexique', 'Francia,México',
#         'Frankreich, Panama, United States', 'en:ch, United States',
#         'France, Polynésie française', 'France,USA',
#         'Frankreich,Deutschland, en:switzerland',
#         'France,Switzerland,United Kingdom',
#         'Costa Rica,España,Estados Unidos',
#         'Francia,México, United States', 'en:Mexico, United States',
#         'España, United States', 'en:Spain', 'Australie, France',
#         'Frankreich,Deutschland,Vereinigtes Königreich,Vereinigte Staaten von Amerika',
#         'Australie, France, États-Unis', 'France, Royaume-Uni, États-Unis',
#         'France,Suisse,États-Unis', 'Países Bajos,Estados Unidos',
#         'France, États-Unis, Switzerland', 'Australia, France',
#         'Spain,United Kingdom', 'France, United States, Switzerland',
#         'en:nc', 'en:PF, United States', 'United States, Germany',
#         'en:my, United States', 'en:ad', 'en:nl',
#         'Trinidad and Tobago, United States',
#         'France,Royaume-Uni,en:france', 'United States,en:sweden',
#         'en:Costa Rica, United States', 'France,en:sweden, United States',
#         'en:CA', 'Jordan', 'Poland', 'ประเทศฝรั่งเศส,สหราชอาณาจักร',
#         'Guadeloupe, United States', 'الولايات المتحدة',
#         'France,USA,United States', 'France, Mexique, United States',
#         'France, United States, Germany', 'en:Mexico'], dtype=object),
#  array(['France', 'United States', 'Canada', 'Belgium',
#         'France,United States', 'Germany', 'United Kingdom', 'Italy',
#         'Spain', 'Portugal', 'Mexico', 'France,United Kingdom',
#         'Belgium,France,Netherlands,United Kingdom', 'Spain,Switzerland',
#         nan, 'Germany,Spain', 'France,Spain', 'Austria,France,Germany',
#         'Mexico,United States', 'Australia',
#         'France,Switzerland,United States', 'United States,Francia-spain',
#         'Canada,Switzerland,United States', 'France,Thailand',
#         'Germany,United States', 'French Polynesia,United States',
#         'United Kingdom,United States', 'Egypt,United States',
#         'Belgium,United States', 'Spain,United States', 'Croatia',
#         'Canada,France', 'Haiti', 'Singapore',
#         'Australia,Belgium,France,Germany,Switzerland', 'Switzerland',
#         'Belgium,Spain', 'Belgium,France', 'France,Germany',
#         'France,Switzerland', 'Australia,France,New Zealand',
#         'French Polynesia', 'Australia,United States', 'Saudi Arabia',
#         'United Arab Emirates', 'Switzerland,United States', 'Colombia',
#         'Czech Republic,France,United States',
#         'United States,العراق,فرنسا', 'France,New Caledonia', 'Sweden',
#         'Saudi Arabia,United States',
#         'Australia,France,Sweden,United States', 'Sweden,United States',
#         'Austria,Germany,Sweden,United States', 'Vietnam',
#         'Martinique,United States', 'France,United Kingdom,United States',
#         'France,Mexico,United States', 'France,Spain,Switzerland',
#         'France,Switzerland,United Kingdom',
#         'France,French Polynesia,United States', 'France,Mexico',
#         'Australia,New Zealand,Singapore,Thailand,United States',
#         'France,French Polynesia', 'Puerto Rico,United States',
#         'France,Spain,United States', 'India,Spain,United States',
#         'Costa Rica', 'Colombia,Spain', 'Lebanon,United States',
#         'Canada,United States', 'United Arab Emirates,United States',
#         'France,New Caledonia,United States',
#         'France,Germany,United States', 'New Caledonia,United States',
#         'France,Panama,United States', 'France,Germany,Switzerland',
#         'Costa Rica,Spain,United States', 'Australia,France',
#         'France,Germany,United States,Vereinigtes-konigreich',
#         'Australia,France,United States', 'Netherlands,United States',
#         'Spain,United Kingdom', 'New Caledonia', 'Malaysia,United States',
#         'Andorra', 'Netherlands', 'Trinidad and Tobago,United States',
#         'Costa Rica,United States', 'France,Sweden,United States',
#         'Jordan', 'Poland', 'Guadeloupe,United States'], dtype=object))

# %% [markdown]
# Notons une similitude des modalités des pays, des différences de traduction sont détectées, le dédoublonnage est donc recommandé.

# %%
openfoodfacts.drop(columns='countries', inplace=True)

# %% [markdown]
# `serving_size / serving_quantity`

# %%
display_duplicate_var(openfoodfacts, 'serving_size', 'serving_quantity')
# Out:
# (array([nan, '30 g (0.25 cup)', '285 g', ..., '1.5 ONZ (40 g)',
#         '2 Tbsp (56 g)', '0.25 cup (85 g)'], dtype=object),
#  array([           nan, 3.00000000e+01, 2.85000000e+02, 3.00000000e+02,
#         1.00000000e+02, 1.70000000e+02, 1.50000000e+02, 9.00000000e+01,
#         3.30000000e+02, 2.80000000e+02, 4.00000000e+01, 8.50000000e+01,
#         1.25000000e+01, 1.13500000e+02, 4.26000000e+01, 1.50000000e+01,
#         1.76000000e+01, 1.40000000e+01, 5.70000000e+01, 2.10000000e+01,
#         3.40000000e+01, 3.90000000e+01, 3.20000000e+01, 2.50000000e+01,
#         2.80000000e+01, 7.10000000e+01, 1.17000000e+02, 2.20000000e+01,
#         5.60000000e+01, 4.30000000e+01, 3.60000000e+01, 3.80000000e+01,
#         3.50000000e+01, 1.28000000e+02, 8.20000000e+01, 8.90000000e+01,
#         1.48000000e+02, 1.20000000e+02, 8.40000000e+01, 1.10000000e+02,
#         3.70000000e+01, 3.25000000e+02, 2.40000000e+02, 2.00000000e+01,
#         2.26800000e+01, 1.00000000e+01, 2.30000000e+01, 4.25000000e+01,
#         2.90000000e+01, 3.00000000e+00, 2.50000000e+02, 4.00000000e+00,
#         5.00000000e+01, 2.00000000e+00, 4.20000000e+01, 3.10000000e+01,
#         7.00000000e+00, 2.60000000e+01, 5.00000000e+00, 1.70000000e+01,
#         3.30000000e+01, 1.30000000e+01, 4.60000000e+01, 2.04600000e+02,
#         1.30000000e+02, 2.15000000e+02, 1.80000000e+02, 2.45000000e+02,
#         1.71000000e+01, 2.25000000e+01, 3.26000000e+02, 3.06000000e+02,
#         1.87500000e+02, 2.35000000e+02, 2.65000000e+02, 3.15000000e+02,
#         2.23800000e+02, 1.96000000e+02, 0.00000000e+00, 2.24600000e+02,
#         3.31500000e+02, 3.21000000e+02, 4.60000000e+02, 3.27000000e+02,
#         2.68500000e+02, 4.30000000e+02, 3.20000000e+02, 1.71000000e+02,
#         3.16000000e+02, 7.00000000e+01, 6.00000000e-01, 2.68000000e+02,
#         2.62800000e+02, 2.16000000e+02, 2.60000000e+02, 2.10000000e+02,
#         4.25000000e+02, 1.22000000e+02, 5.50000000e+01, 1.12000000e+02,
#         6.90000000e+01, 1.33000000e+02, 5.20000000e+01, 1.15000000e+02,
#         6.70000000e+01, 1.35000000e+01, 7.90000000e+00, 4.50000000e+01,
#         1.75000000e+02, 7.70000000e+01, 1.05000000e+02, 1.25000000e+02,
#         1.40000000e+02, 2.00000000e+02, 6.30000000e+01, 1.98000000e+02,
#         6.10000000e+01, 8.30000000e+01, 2.05000000e+02, 6.00000000e+01,
#         9.90000000e+01, 2.25000000e+02, 1.13000000e+02, 2.27000000e+02,
#         2.08000000e+02, 1.76000000e+02, 2.38000000e+02, 1.38000000e+02,
#         9.70000000e+01, 2.92000000e+02, 2.54000000e+02, 2.07000000e+02,
#         2.27000000e+01, 1.54000000e+02, 5.20000000e+02, 1.99000000e+02,
#         2.53000000e+01, 6.25000000e+01, 2.32000000e+01, 2.51600000e+01,
#         4.21700000e+01, 4.21600000e+01, 4.02000000e+01, 7.30000000e-01,
#         1.67000000e+01, 2.52500000e+02, 4.40000000e+02, 2.82000000e+02,
#         1.17000000e+01, 2.53000000e+02, 6.61000000e+01, 2.79000000e+02,
#         2.83500000e+01, 4.29000000e+02, 8.50485694e+01, 5.66000000e+01,
#         2.70000000e+02, 3.80000000e+02, 6.50000000e+00, 2.34000000e+02,
#         9.08000000e+01, 2.12600000e+01, 4.96120000e+01, 8.37500000e+01,
#         1.69000000e+02, 1.93000000e+02, 1.64000000e+02, 1.41000000e+01,
#         2.75000000e+02, 2.67000000e+02, 4.22200000e+03, 1.45000000e+01,
#         1.62000000e+02]))

# %% [markdown]
# Aucune utilité évidente, **la suppression des deux variables est retenue.**

# %%
openfoodfacts.drop(columns=['serving_size', 'serving_quantity'], inplace=True)

# %% [markdown]
# `additives_n / additives_en`

# %%
display_duplicate_var(openfoodfacts, 'additives_n', 'additives_en')
# Out:
# (array([nan,  3.,  0.,  2.,  4.,  8.,  1.,  7.,  5.,  6., 11.,  9., 13.,
#         10., 12., 17., 15., 20., 14., 18., 21., 16., 23., 25., 24., 26.,
#         19., 22., 27., 32.]),
#  array([nan,
#         'E14XX - Modified Starch,E262 - Sodium acetates,E262i - Sodium acetate,E326 - Potassium lactate',
#         'E14XX - Modified Starch,E451 - Triphosphates,E451i - Pentasodium triphosphate',
#         ..., 'E260 - Acetic acid,E330 - Citric acid,E440 - Pectins',
#         'E297 - Fumaric acid,E330 - Citric acid,E440 - Pectins',
#         'E414 - Acacia gum,E415 - Xanthan gum'], dtype=object))

# %% [markdown]
# Information complémentaire sur le produit, le nombre d'additifs + le type d'additif, aucune suppression.

# %% [markdown]
# `ingredients_from_palm_oil_n / ingredients_that_may_be_from_palm_oil_n`

# %%
display(openfoodfacts.ingredients_from_palm_oil_n.unique())
display(openfoodfacts.ingredients_that_may_be_from_palm_oil_n.unique())
# Out:
# array([nan,  0.,  1.])
# array([nan,  0.,  2.,  1.,  3.,  4.])

# %% [markdown]
# Notons que les valeurs de la variable 'ingredients_from_palm_oil_n' font penser à un choix binaire, présence d'ingrédients d'huile de palme (1:oui - 0:non). Sans explication complémentaire (dans l'immédiat), les deux variables sont conservées pour deux raisons. Le degré de complétude est supérieur à 97%, et la notion d'huile de palme pourrait avoir une forte importance dans le Nutri-score, le caractère graisse végétale est à prendre en compte.

# %% [markdown]
# `states / states_en`

# %%
display_duplicate_var(openfoodfacts, 'states', 'states_en')
# Out:
# (array(['en:to-be-completed, en:nutrition-facts-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:categories-completed, en:brands-to-be-completed, en:packaging-to-be-completed, en:quantity-to-be-completed, en:product-name-completed, en:photos-to-be-validated, en:photos-uploaded',
#         'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-to-be-completed, en:product-name-completed, en:photos-to-be-validated, en:photos-uploaded',
#         'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-to-be-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:categories-completed, en:brands
ated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands to be completed,Packaging completed,Quantity to be completed,Product name completed,Photos to be validated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients completed,Expiration date completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands to be completed,Packaging to be completed,Quantity completed,Product name completed,Photos to be validated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients to be completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands completed,Packaging completed,Quantity to be completed,Product name completed,Photos validated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients to be completed,Expiration date completed,Packaging code completed,Characteristics completed,Categories completed,Brands completed,Packaging completed,Quantity completed,Product name completed,Photos validated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands to be completed,Packaging completed,Quantity completed,Product name completed,Photos to be validated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients to be completed,Expiration date to be completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands to be completed,Packaging completed,Quantity to be completed,Product name completed,Photos validated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients completed,Expiration date completed,Packaging code to be completed,Characteristics to be completed,Categories completed,Brands to be completed,Packaging to be completed,Quantity to be completed,Product name completed,Photos to be validated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients to be completed,Expiration date completed,Packaging code to be completed,Characteristics completed,Categories completed,Brands completed,Packaging completed,Quantity completed,Product name completed,Photos validated,Photos uploaded',
#         'Checked,Complete,Nutrition facts completed,Ingredients completed,Expiration date to be completed,Packaging code to be completed,Characteristics completed,Categories completed,Brands completed,Packaging completed,Quantity completed,Product name completed,Photos validated,Photos uploaded',
#         'To be completed,Nutrition facts completed,Ingredients completed,Expiration date to be completed,Packaging code completed,Characteristics to be completed,Categories completed,Brands completed,Packaging to be completed,Quantity to be completed,Product name completed,Photos validated,Photos uploaded'],
#        dtype=object))

# %%
openfoodfacts.drop(columns='states_en', inplace=True)

# %%
openfoodfacts.shape
# Out:
# (20166, 38)

# %% [markdown]
# ### Nettoyage et pré-traitement des observations
# Vérifications complémentaires des éventuelles observations en doublon, sans désignation, etc…

# %%
def sample_clean(data, product_variable):
    """Suppression des observations selon les conditions suivantes :
        - noms de produits manquants
        - Code + nom de produit en doublon"""
    data = data[~data[product_variable].isna()]
    data = data[~data.duplicated(subset=['code', 'product_name'], keep=False)]
    return data

openfoodfacts = sample_clean(openfoodfacts, 'product_name')
display(openfoodfacts.shape)
display(openfoodfacts.head())
# Out:
# (20164, 38)
#     code                                                url  creator  \
# 13   949  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 21  1281  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 31  1885  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 35  2257  http://world-en.openfoodfacts.org/product/0000...  kiliweb
# 59  5005  http://world-en.openfoodfacts.org/product/0000...  kiliweb
#
#              created_t     last_modified_t                    product_name  \
# 13 2018-04-11 10:00:13 2019-08-08 12:46:52       Salade de carottes râpées
# 21 2018-02-05 11:40:01 2018-05-23 10:19:54              Tarte noix de coco
# 31 2017-11-20 12:18:57 2018-02-08 21:48:11                Compote de poire
# 35 2018-03-08 10:48:42 2019-06-25 11:55:49  Salade de macedoine de légumes
# 59 2018-03-21 20:21:24 2018-12-27 18:11:12                       Abondance
#
#                 brands                                         categories  \
# 13                 NaN  Plats préparés, Légumes préparés, Carottes râp...
# 21  Crous Resto',Crous   Tartes, Tartes sucrées, Tartes à la noix de coco
# 31               Crous  Aliments et boissons à base de végétaux, Alime...
# 35                 NaN  Plats préparés, Légumes préparés, Entrées, Ent...
# 59                 NaN  Produits laitiers, Produits fermentés, Produit...
#
#    countries_en ingredients_text  ...  sugars_100g fiber_100g  proteins_100g  \
# 13       France              NaN  ...          3.9        NaN            0.9
# 21       France              NaN  ...         21.9        4.4            4.6
# 31       France              NaN  ...         27.0        3.6            0.6
# 35       France              NaN  ...          1.0        NaN            1.9
# 59       France              NaN  ...          0.1        NaN           25.0
#
#     salt_100g sodium_100g  vitamin-a_100g vitamin-c_100g calcium_100g  \
# 13       0.42       0.168             NaN            NaN          NaN
# 21       0.10       0.040             NaN            NaN          NaN
# 31       0.00       0.000             NaN            NaN          NaN
# 35       0.27       0.108             NaN            NaN          NaN
# 59       1.30       0.520             NaN            NaN          NaN
#
#    iron_100g nutrition-score-fr_100g
# 13       NaN                     1.0
# 21       NaN                    14.0
# 31       NaN                    -2.0
# 35       NaN                     1.0
# 59       NaN                    14.0
#
# [5 rows x 38 columns]

# %%
openfoodfacts.describe(exclude=[np.object]).T
# Out:
#                                          count unique                 top  \
# created_t                                20164  12234 2017-03-09 09:59:38
# last_modified_t                          20164  12027 2020-04-23 07:44:06
# additives_n                              19471    NaN                 NaT
# ingredients_from_palm_oil_n              19471    NaN                 NaT
# ingredients_that_may_be_from_palm_oil_n  19471    NaN                 NaT
# nova_group                               18935    NaN                 NaT
# energy_100g                              20164    NaN                 NaT
# fat_100g                                 20164    NaN                 NaT
# saturated-fat_100g                       20163    NaN                 NaT
# trans-fat_100g                           18377    NaN                 NaT
# cholesterol_100g                         18581    NaN                 NaT
# carbohydrates_100g                       20163    NaN                 NaT
# sugars_100g                              20163    NaN                 NaT
# fiber_100g                               19040    NaN                 NaT
# proteins_100g                            20164    NaN                 NaT
# salt_100g                                20164    NaN                 NaT
# sodium_100g                              20164    NaN                 NaT
# vitamin-a_100g                           15616    NaN                 NaT
# vitamin-c_100g                           15788    NaN                 NaT
# calcium_100g                             18233    NaN                 NaT
# iron_100g                                18361    NaN                 NaT
# nutrition-score-fr_100g                  20164    NaN                 NaT
#
#                                         freq               first  \
# created_t                                 12 2012-04-27 14:47:56
# last_modified_t                           12 2014-11-24 23:59:16
# additives_n                              NaN                 NaT
# ingredients_from_palm_oil_n              NaN                 NaT
# ingredients_that_may_be_from_palm_oil_n  NaN                 NaT
# nova_group                               NaN                 NaT
# energy_100g                              NaN                 NaT
# fat_100g                                 NaN                 NaT
# saturated-fat_100g                       NaN                 NaT
# trans-fat_100g                           NaN                 NaT
# cholesterol_100g                         NaN                 NaT
# carbohydrates_100g                       NaN                 NaT
# sugars_100g                              NaN                 NaT
# fiber_100g                               NaN                 NaT
# proteins_100g                            NaN                 NaT
# salt_100g                                NaN                 NaT
# sodium_100g                              NaN                 NaT
# vitamin-a_100g                           NaN                 NaT
# vitamin-c_100g                           NaN                 NaT
# calcium_100g                             NaN                 NaT
# iron_100g                                NaN                 NaT
# nutrition-score-fr_100g                  NaN                 NaT
#
#                                                        last         mean  \
# created_t                               2020-09-27 13:24:37          NaN
# last_modified_t                         2020-09-28 17:08:51          NaN
# additives_n                                             NaT      2.90976
# ingredients_from_palm_oil_n                             NaT   0.00220841
# ingredients_that_may_be_from_palm_oil_n                 NaT    0.0582918
# nova_group                                              NaT      3.47262
# energy_100g                                             NaT      1184.34
# fat_100g                                                NaT      12.6375
# saturated-fat_100g                                      NaT      4.55784
# trans-fat_100g                                          NaT    0.0493835
# cholesterol_100g                                        NaT     0.028059
# carbohydrates_100g                                      NaT      35.8708
# sugars_100g                                             NaT      15.6829
# fiber_100g                                              NaT      2.60879
# proteins_100g                                           NaT      7.46449
# salt_100g                                               NaT       1.4735
# sodium_100g                                             NaT     0.589596
# vitamin-a_100g                                          NaT  0.000122846
# vitamin-c_100g                                          NaT   0.00623916
# calcium_100g                                            NaT    0.0880174
# iron_100g                                               NaT   0.00303975
# nutrition-score-fr_100g                                 NaT      9.12359
#
#                                                 std  min    25%     50%  \
# created_t                                       NaN  NaN    NaN     NaN
# last_modified_t                                 NaN  NaN    NaN     NaN
# additives_n                                 3.70718    0      0       2
# ingredients_from_palm_oil_n                0.046943    0      0       0
# ingredients_that_may_be_from_palm_oil_n    0.246479    0      0       0
# nova_group                                 0.962088    1      3       4
# energy_100g                                 748.428    0    456    1255
# fat_100g                                    15.6031    0   0.42    6.19
# saturated-fat_100g                          7.05421    0      0    1.61
# trans-fat_100g                             0.707541    0      0       0
# cholesterol_100g                           0.938676    0      0       0
# carbohydrates_100g                          28.6316    0    9.3   28.09
# sugars_100g                                 19.5488    0   1.79    6.25
# fiber_100g                                   4.0895    0      0     1.4
# proteins_100g                               7.97356    0    1.9    5.26
# salt_100g                                   23.9731    0  0.135  0.7075
# sodium_100g                                 9.61686    0  0.054   0.283
# vitamin-a_100g                           0.00043299    0      0       0
# vitamin-c_100g                            0.0252473    0      0       0
# calcium_100g                               0.207275    0      0   0.033
# iron_100g                                  0.142451    0      0  0.0009
# nutrition-score-fr_100g                      9.1945  -14      1      11
#
#                                               75%      max
# created_t                                     NaN      NaN
# last_modified_t                               NaN      NaN
# additives_n                                     4       32
# ingredients_from_palm_oil_n                     0        1
# ingredients_that_may_be_from_palm_oil_n         0        4
# nova_group                                      4        4
# energy_100g                                  1699    10594
# fat_100g                                       20      100
# saturated-fat_100g                           6.67    92.86
# trans-fat_100g                                  0    44.25
# cholesterol_100g                            0.019  116.915
# carbohydrates_100g                          62.79      133
# sugars_100g                                    25      100
# fiber_100g                                    3.5      100
# proteins_100g                                  10      110
# salt_100g                                    1.37     3340
# sodium_100g                                 0.548     1340
# vitamin-a_100g                           9.99e-05    0.015
# vitamin-c_100g                              0.003     0.66
# calcium_100g                                0.104     11.5
# iron_100g                                  0.0024     19.2
# nutrition-score-fr_100g                        16       36

# %% [markdown]
# Les métriques min. et max. sont très utiles pour savoir si oui ou non des valeurs outliers sont à traiter.\
# **Voyons les critères d'identification de ces valeurs sur les données nutritionnelles.**

# %% [markdown]
# ### Traitement des outliers
# **Rappelons les conditions du fonctionnement du Nutri-Score**\
# Ici les nutriments et aliments à favoriser (fibres, protéines, fruits et légumes) s'expriment en teneur pour 100 grammes de produit. Au-dessus de 100g la valeur peut-être considérée comme "aberrante".
#
# Concernant les nutriments à limiter (énergie, acides gras saturés, sucres, sel), l'énergie nutritionnelle s'exprime en Kj. Afin de déterminer un "seuil", considérons que la moyenne nutritionnelle journalière pour un adulte est d'environ 2000 kcal (1kJ = 0.239kcal). Cette valeur sera considérée outlier à partir de 2000kcal (8373,6kJ) pour 100g de produit.

# %%
def outlier_count(data, regex, limit):
    for var in data.loc[:, data.columns.str.contains(regex)].columns :
        print(var + ' : ' + str(len(data[data[var] > limit])))

# %%
outlier_count(openfoodfacts, '^(?!energy).*_100g.*', 100)
# Out:
# fat_100g : 0
# saturated-fat_100g : 0
# trans-fat_100g : 0
# cholesterol_100g : 1
# carbohydrates_100g : 1
# sugars_100g : 0
# fiber_100g : 0
# proteins_100g : 1
# salt_100g : 3
# sodium_100g : 1
# vitamin-a_100g : 0
# vitamin-c_100g : 0
# calcium_100g : 0
# iron_100g : 0
# nutrition-score-fr_100g : 0

# %%
outlier_count(openfoodfacts, '^energy*', 8373.6)
# Out:
# energy_100g : 1

# %% [markdown]
# Les outliers identifiés ne représentent qu'une part négligeable des données. **Identification des produits concernés avant traitement ou suppression.**

# %%
display(openfoodfacts[openfoodfacts.cholesterol_100g > 100])
display(openfoodfacts[openfoodfacts.proteins_100g > 100])
display(openfoodfacts[openfoodfacts.carbohydrates_100g > 100])
display(openfoodfacts[openfoodfacts.salt_100g > 100])
display(openfoodfacts[openfoodfacts.sodium_100g > 100]) 
display(openfoodfacts[openfoodfacts.energy_100g > 8373.6])
# Out:
#               code                                                url  \
# 19515  13800747785  http://world-en.openfoodfacts.org/product/0013...
#
#                  creator           created_t     last_modified_t  \
# 19515  org-database-usda 2020-04-23 10:08:20 2020-04-23 10:08:20
#
#                                             product_name brands categories  \
# 19515  Scrambled eggs, roasted russet potatoes & saus...    NaN      Meals
#
#         countries_en                                   ingredients_text  ...  \
# 19515  United States  Eggs & potatoes: cooked scrambled eggs (whole ...  ...
#
#        sugars_100g fiber_100g  proteins_100g  salt_100g sodium_100g  \
# 19515         1.49        1.0           8.46     0.9325       0.373
#
#        vitamin-a_100g vitamin-c_100g calcium_100g iron_100g  \
# 19515        0.000149         0.0012          0.1    0.0009
#
#       nutrition-score-fr_100g
# 19515                     2.0
#
# [1 rows x 38 columns]
#          code                                                url  \
# 16668  118668  http://world-en.openfoodfacts.org/product/0011...
#
#                           creator           created_t     last_modified_t  \
# 16668  openfoodfacts-contributors 2018-09-14 16:09:54 2019-02-04 21:20:30
#
#       product_name  brands                                         categories  \
# 16668         skyr  migros  Produits laitiers, Produits fermentés, Produit...
#
#       countries_en                                   ingredients_text  ...  \
# 16668  Switzerland  séré maigre au lait pasteurisé élaboré avec du...  ...
#
#        sugars_100g fiber_100g  proteins_100g  salt_100g sodium_100g  \
# 16668          4.0        0.0          110.0        0.1        0.04
#
#        vitamin-a_100g vitamin-c_100g calcium_100g iron_100g  \
# 16668             NaN            NaN          NaN       NaN
#
#       nutrition-score-fr_100g
# 16668                    -5.0
#
# [1 rows x 38 columns]
#               code                                                url  \
# 19045  13600000691  http://world-en.openfoodfacts.org/product/0013...
#
#                           creator           created_t     last_modified_t  \
# 19045  openfoodfacts-contributors 2018-11-07 23:06:48 2020-04-03 21:16:34
#
#       product_name  brands  categories countries_en  \
# 19045       Truvia  Truvia  Sweeteners       Canada
#
#                                         ingredients_text  ...  sugars_100g  \
# 19045  ERYTHRITOL, STEVIA LEAF EXTRACT, NATURAL FLAVOURS  ...          0.0
#
#       fiber_100g  proteins_100g  salt_100g sodium_100g  vitamin-a_100g  \
# 19045        0.0            0.0        0.0         0.0             NaN
#
#       vitamin-c_100g calcium_100g iron_100g nutrition-score-fr_100g
# 19045            NaN          NaN       NaN                     0.0
#
# [1 rows x 38 columns]
#               code                                                url  \
# 2357         62251  http://world-en.openfoodfacts.org/product/0006...
# 9496   11110980410  http://world-en.openfoodfacts.org/product/0011...
# 25751  16073622346  http://world-en.openfoodfacts.org/product/0016...
#
#                           creator           created_t     last_modified_t  \
# 2357                waistline-app 2019-05-07 06:02:15 2019-07-11 09:48:15
# 9496   openfoodfacts-contributors 2019-05-23 15:33:54 2019-07-18 07:36:09
# 25751  openfoodfacts-contributors 2019-02-27 13:52:12 2019-02-27 13:57:51
#
#                               product_name             brands  \
# 2357   Cream Line Whole Milk Yogurt: Plain       Trader Joe's
# 9496                    Smoked Coho Salmon  Private Selection
# 25751      Betty Lou's Apple Cinnamon Bars        Betty Lou's
#
#                                               categories   countries_en  \
# 2357   Dairies, Fermented foods, Fermented milk produ...  United States
# 9496   Seafood, Fishes, Salmons, Smoked fishes, Smoke...  United States
# 25751                                     Breakfast bars  United States
#
#                                         ingredients_text  ...  sugars_100g  \
# 2357                                                 NaN  ...         5.29
# 9496                                                 NaN  ...         1.75
# 25751  apple fruit filling, mixed fruit juice concent...  ...        24.00
#
#       fiber_100g  proteins_100g  salt_100g sodium_100g  vitamin-a_100g  \
# 2357         0.0           4.41      157.0       62.70             NaN
# 9496         0.0          22.80     3340.0     1340.00             NaN
# 25751        4.0           1.00      228.6       91.44             NaN
#
#       vitamin-c_100g calcium_100g iron_100g nutrition-score-fr_100g
# 2357             NaN          NaN       NaN                    13.0
# 9496             NaN          NaN       NaN                    14.0
# 25751            NaN          NaN       NaN                    13.0
#
# [3 rows x 38 columns]
#              code                                                url  \
# 9496  11110980410  http://world-en.openfoodfacts.org/product/0011...
#
#                          creator           created_t     last_modified_t  \
# 9496  openfoodfacts-contributors 2019-05-23 15:33:54 2019-07-18 07:36:09
#
#             product_name             brands  \
# 9496  Smoked Coho Salmon  Private Selection
#
#                                              categories   countries_en  \
# 9496  Seafood, Fishes, Salmons, Smoked fishes, Smoke...  United States
#
#      ingredients_text  ...  sugars_100g fiber_100g  proteins_100g  salt_100g  \
# 9496              NaN  ...         1.75        0.0           22.8     3340.0
#
#      sodium_100g  vitamin-a_100g vitamin-c_100g calcium_100g iron_100g  \
# 9496      1340.0             NaN            NaN          NaN       NaN
#
#      nutrition-score-fr_100g
# 9496                    14.0
#
# [1 rows x 38 columns]
#      code                                                url  \
# 1472  147  http://world-en.openfoodfacts.org/product/0001...
#
#                          creator           created_t     last_modified_t  \
# 1472  openfoodfacts-contributors 2020-04-12 13:09:55 2020-05-12 19:56:23
#
#        product_name       brands              categories countries_en  \
# 1472  Açai en polvo  NaturaleBio  Suplementos dietéticos        Spain
#
#      ingredients_text  ...  sugars_100g fiber_100g  proteins_100g  salt_100g  \
# 1472             Açai  ...          1.0       20.0            9.0        0.0
#
#      sodium_100g  vitamin-a_100g vitamin-c_100g calcium_100g iron_100g  \
# 1472         0.0        0.000645            NaN        0.217   0.00416
#
#      nutrition-score-fr_100g
# 1472                     5.0
#
# [1 rows x 38 columns]

# %%
def drop_outliers(data, regex, limit):
    for var in data.loc[:, data.columns.str.contains(regex)]:
        indexNames = data[data[var] > limit].index
        data.drop(indexNames , inplace=True)
    return data

#drop_outliers(openfoodfacts, '^(?!energy).*_100g.*', 100)        
#drop_outliers(openfoodfacts, '^energy*', 8373.6)

# %% [markdown]
# Notons que ces 8 produits sont proposés soit en Suisse, Canada, USA ou Espagne. Il ne semble pas que ces teneurs soient aberrantes, certainement liées à leur pays d'origine. Ceci étant, ces 8 produits peuvent être supprimés, ou laissés sans aucune modification.
#
# **La dernière possibilité sera retenue, car ces valeurs un peu au dessus des seuils attendus ne concernent qu'une part négligeable d'observations.**

# %% [markdown]
# ### Traitement des pays
# L'échantillon ne concerne pas que notre pays la France, mais d'autres pays du Monde. Dans le contexte d'élaboration d'une application ayant pour principale vocation de renseigner le consommateurs sur le Nutri Score, la variable pays n'aura peut-être pas d'utilité première. Ceci étant, il est important d'avoir une idée du poids de la France dans l'échantillon par rapport aux autres pays.

# %%
openfoodfacts.countries_en.unique()
# Out:
# array(['France', 'United States', 'Canada', 'Belgium',
#        'France,United States', 'Germany', 'United Kingdom', 'Italy',
#        'Spain', 'Portugal', 'Mexico', 'France,United Kingdom',
#        'Belgium,France,Netherlands,United Kingdom', 'Spain,Switzerland',
#        nan, 'Germany,Spain', 'France,Spain', 'Austria,France,Germany',
#        'Mexico,United States', 'Australia',
#        'France,Switzerland,United States', 'United States,Francia-spain',
#        'Canada,Switzerland,United States', 'France,Thailand',
#        'Germany,United States', 'French Polynesia,United States',
#        'United Kingdom,United States', 'Egypt,United States',
#        'Belgium,United States', 'Spain,United States', 'Croatia',
#        'Canada,France', 'Haiti', 'Singapore',
#        'Australia,Belgium,France,Germany,Switzerland', 'Switzerland',
#        'Belgium,Spain', 'Belgium,France', 'France,Germany',
#        'France,Switzerland', 'Australia,France,New Zealand',
#        'French Polynesia', 'Australia,United States', 'Saudi Arabia',
#        'United Arab Emirates', 'Switzerland,United States', 'Colombia',
#        'Czech Republic,France,United States',
#        'United States,العراق,فرنسا', 'France,New Caledonia', 'Sweden',
#        'Saudi Arabia,United States',
#        'Australia,France,Sweden,United States', 'Sweden,United States',
#        'Austria,Germany,Sweden,United States', 'Vietnam',
#        'Martinique,United States', 'France,United Kingdom,United States',
#        'France,Mexico,United States', 'France,Spain,Switzerland',
#        'France,Switzerland,United Kingdom',
#        'France,French Polynesia,United States', 'France,Mexico',
#        'Australia,New Zealand,Singapore,Thailand,United States',
#        'France,French Polynesia', 'Puerto Rico,United States',
#        'France,Spain,United States', 'India,Spain,United States',
#        'Costa Rica', 'Colombia,Spain', 'Lebanon,United States',
#        'Canada,United States', 'United Arab Emirates,United States',
#        'France,New Caledonia,United States',
#        'France,Germany,United States', 'New Caledonia,United States',
#        'France,Panama,United States', 'France,Germany,Switzerland',
#        'Costa Rica,Spain,United States', 'Australia,France',
#        'France,Germany,United States,Vereinigtes-konigreich',
#        'Australia,France,United States', 'Netherlands,United States',
#        'Spain,United Kingdom', 'New Caledonia', 'Malaysia,United States',
#        'Andorra', 'Netherlands', 'Trinidad and Tobago,United States',
#        'Costa Rica,United States', 'France,Sweden,United States',
#        'Jordan', 'Poland', 'Guadeloupe,United States'], dtype=object)

# %% [markdown]
# Les données ne sont pas exploitables en l'état, une fonction est nécessaire à son traitement.

# %%
def country_list(data, country_variable):
    country_tags = {}
    for i in data.index:
        tags = str(data.at[i, country_variable]).split(",")
        for tag in tags:
            if tag in country_tags:
                country_tags[tag] += 1
            else:
                country_tags[tag] = 1

    sorted_labels_tags = sorted(country_tags, key=country_tags.get, reverse=True)

    for tag in sorted_labels_tags[:]:
        print(f"{tag}: {country_tags[tag]}")
        
        
country_list(openfoodfacts, 'countries_en')
# Out:
# United States: 18977
# France: 1124
# United Kingdom: 284
# Spain: 227
# Mexico: 70
# Germany: 40
# Canada: 29
# Switzerland: 22
# Australia: 16
# Belgium: 15
# French Polynesia: 9
# Sweden: 8
# Singapore: 6
# Italy: 5
# Netherlands: 5
# New Caledonia: 5
# Costa Rica: 5
# nan: 4
# United Arab Emirates: 4
# Thailand: 3
# Saudi Arabia: 3
# Colombia: 3
# Austria: 2
# New Zealand: 2
# Portugal: 1
# Francia-spain: 1
# Egypt: 1
# Croatia: 1
# Haiti: 1
# Czech Republic: 1
# العراق: 1
# فرنسا: 1
# Vietnam: 1
# Martinique: 1
# Puerto Rico: 1
# India: 1
# Lebanon: 1
# Panama: 1
# Vereinigtes-konigreich: 1
# Malaysia: 1
# Andorra: 1
# Trinidad and Tobago: 1
# Jordan: 1
# Poland: 1
# Guadeloupe: 1

# %% [markdown]
# **Notons que la France est représentative de l'échantillon juste après les USA.**
#
# L'agence **"Santé publique France"** est à l'origine de l'appel à projets pour trouver des idées innovantes d’applications en lien avec l'alimentation, le choix de se limiter uniquement aux produits vendus en France peut sembler pertinent. Mais cette option serait contre productive pour les raisons suivantes :
#
# - L'objectif final d'application sera l'attribution d'un Nutri-score quand celui-ci est inexistant
# - Les teneurs nutritionnelles sont universelles quelque soit le pays de vente
# - Le but est et sera toujours la qualité des données, l'équilibre entre les données manquantes et celles disponibles
# - Ci-dessous les explications…

# %%
openfoodfacts_france = openfoodfacts[openfoodfacts['countries_en']
                                     .str.contains('France', case=False) == True]
openfoodfacts_france
# Out:
#               code                                                url  \
# 13             949  http://world-en.openfoodfacts.org/product/0000...
# 21            1281  http://world-en.openfoodfacts.org/product/0000...
# 31            1885  http://world-en.openfoodfacts.org/product/0000...
# 35            2257  http://world-en.openfoodfacts.org/product/0000...
# 59            5005  http://world-en.openfoodfacts.org/product/0000...
# ...            ...                                                ...
# 32171  20009494822  http://world-en.openfoodfacts.org/product/0020...
# 32174  20009495935  http://world-en.openfoodfacts.org/product/0020...
# 32176  20009799613  http://world-en.openfoodfacts.org/product/0020...
# 32179  20011083908  http://world-en.openfoodfacts.org/product/0020...
# 32299  20138136044  http://world-en.openfoodfacts.org/product/0020...
#
#                creator           created_t     last_modified_t  \
# 13             kiliweb 2018-04-11 10:00:13 2019-08-08 12:46:52
# 21             kiliweb 2018-02-05 11:40:01 2018-05-23 10:19:54
# 31             kiliweb 2017-11-20 12:18:57 2018-02-08 21:48:11
# 35             kiliweb 2018-03-08 10:48:42 2019-06-25 11:55:49
# 59             kiliweb 2018-03-21 20:21:24 2018-12-27 18:11:12
# ...                ...                 ...                 ...
# 32171          kiliweb 2019-09-09 05:49:12 2019-12-19 17:57:09
# 32174          kiliweb 2018-04-04 11:11:43 2018-09-19 18:35:38
# 32176          kiliweb 2018-11-14 18:36:52 2020-04-15 22:37:09
# 32179          kiliweb 2018-05-24 08:39:26 2019-11-21 20:43:11
# 32299  usda-ndb-import 2017-03-09 12:44:12 2020-04-22 18:04:40
#
#                            product_name  \
# 13            Salade de carottes râpées
# 21                   Tarte noix de coco
# 31                     Compote de poire
# 35       Salade de macedoine de légumes
# 59                            Abondance
# ...                                 ...
# 32171             Tartelettes framboise
# 32174                    Flan Nature *2
# 32176             Pudding 6/8 personnes
# 32179             Baguette aux céréales
# 32299  Roasted raspberry chipotle sauce
#
#                                        brands  \
# 13                                        NaN
# 21                         Crous Resto',Crous
# 31                                      Crous
# 35                                        NaN
# 59                                        NaN
# ...                                       ...
# 32171                                     NaN
# 32174                                 Leclerc
# 32176                                 Leclerc
# 32179                                     NaN
# 32299  Fischer & Wieser Specialty Foods  Inc.
#
#                                               categories  \
# 13     Plats préparés, Légumes préparés, Carottes râp...
# 21      Tartes, Tartes sucrées, Tartes à la noix de coco
# 31     Aliments et boissons à base de végétaux, Alime...
# 35     Plats préparés, Légumes préparés, Entrées, Ent...
# 59     Produits laitiers, Produits fermentés, Produit...
# ...                                                  ...
# 32171    Tartes, Tartelettes, Tartelettes à la framboise
# 32174  Snacks, Snacks sucrés, Biscuits et gâteaux, Pâ...
# 32176                                 Desserts, Puddings
# 32179  Aliments et boissons à base de végétaux, Alime...
# 32299                                  Groceries, Sauces
#
#                countries_en  \
# 13                   France
# 21                   France
# 31                   France
# 35                   France
# 59                   France
# ...                     ...
# 32171                France
# 32174                France
# 32176                France
# 32179                France
# 32299  France,United States
#
#                                         ingredients_text  ...  sugars_100g  \
# 13                                                   NaN  ...         3.90
# 21                                                   NaN  ...        21.90
# 31                                                   NaN  ...        27.00
# 35                                                   NaN  ...         1.00
# 59                                                   NaN  ...         0.10
# ...                                                  ...  ...          ...
# 32171                                                NaN  ...         7.74
# 32174  _Lait_ écrémé , sucre, farine de _blé_ (_glute...  ...        22.00
# 32176                                                NaN  ...        25.60
# 32179                                                NaN  ...         2.28
# 32299  Red raspberries, pure cane sugar, jalapenos (j...  ...        45.00
#
#       fiber_100g  proteins_100g  salt_100g sodium_100g  vitamin-a_100g  \
# 13           NaN           0.90       0.42       0.168             NaN
# 21           4.4           4.60       0.10       0.040             NaN
# 31           3.6           0.60       0.00       0.000             NaN
# 35           NaN           1.90       0.27       0.108             NaN
# 59           NaN          25.00       1.30       0.520             NaN
# ...          ...            ...        ...         ...             ...
# 32171        NaN           3.12       0.36       0.144             NaN
# 32174        NaN           3.70       0.37       0.148             NaN
# 32176        NaN           2.80       1.60       0.640             NaN
# 32179        NaN           8.40       1.50       0.600             NaN
# 32299        5.0           0.00       0.75       0.300             0.0
#
#       vitamin-c_100g calcium_100g iron_100g nutrition-score-fr_100g
# 13               NaN          NaN       NaN                     1.0
# 21               NaN          NaN       NaN                    14.0
# 31               NaN          NaN       NaN                    -2.0
# 35               NaN          NaN       NaN                     1.0
# 59               NaN          NaN       NaN                    14.0
# ...              ...          ...       ...                     ...
# 32171            NaN          NaN       NaN                     8.0
# 32174            NaN          NaN       NaN                    15.0
# 32176            NaN          NaN       NaN                    19.0
# 32179            NaN          NaN       NaN                     5.0
# 32299            NaN          NaN       NaN                     9.0
#
# [1124 rows x 38 columns]

# %%
missing_value_clean(openfoodfacts_france)
# Out:
# nutrition-score-fr_100g                    100.0
# energy_100g                                100.0
# url                                        100.0
# creator                                    100.0
# created_t                                  100.0
# last_modified_t                            100.0
# product_name                               100.0
# categories                                 100.0
# countries_en                               100.0
# nutriscore_grade                           100.0
# pnns_groups_1                              100.0
# pnns_groups_2                              100.0
# main_category                              100.0
# main_category_en                           100.0
# states                                     100.0
# fat_100g                                   100.0
# sugars_100g                                100.0
# sodium_100g                                100.0
# salt_100g                                  100.0
# proteins_100g                              100.0
# saturated-fat_100g                         100.0
# code                                       100.0
# carbohydrates_100g                         100.0
# brands                                      76.0
# ingredients_that_may_be_from_palm_oil_n     70.0
# ingredients_from_palm_oil_n                 70.0
# additives_n                                 70.0
# ingredients_text                            70.0
# nova_group                                  64.0
# fiber_100g                                  58.0
# additives_en                                48.0
# brand_owner                                 31.0
# trans-fat_100g                              28.0
# cholesterol_100g                            27.0
# iron_100g                                   27.0
# calcium_100g                                27.0
# vitamin-c_100g                              25.0
# vitamin-a_100g                              23.0
# dtype: float64

# %% [markdown]
# Un choix de restriction sur un seul pays (France), pourtant très représentatif de l'échantillon, n'est pas la meilleure option, très peu de données ≃ 1100 observations et des valeurs manquantes. Voyons une autre possibilité…

# %%
display(openfoodfacts.shape)
display(missing_value_clean(openfoodfacts))
# Out:
# (20164, 38)
# nutrition-score-fr_100g                    100.0
# energy_100g                                100.0
# url                                        100.0
# creator                                    100.0
# created_t                                  100.0
# last_modified_t                            100.0
# product_name                               100.0
# categories                                 100.0
# countries_en                               100.0
# nutriscore_grade                           100.0
# pnns_groups_1                              100.0
# pnns_groups_2                              100.0
# main_category                              100.0
# main_category_en                           100.0
# states                                     100.0
# fat_100g                                   100.0
# sugars_100g                                100.0
# sodium_100g                                100.0
# salt_100g                                  100.0
# proteins_100g                              100.0
# saturated-fat_100g                         100.0
# code                                       100.0
# carbohydrates_100g                         100.0
# ingredients_that_may_be_from_palm_oil_n     97.0
# ingredients_from_palm_oil_n                 97.0
# additives_n                                 97.0
# ingredients_text                            97.0
# nova_group                                  94.0
# fiber_100g                                  94.0
# cholesterol_100g                            92.0
# brand_owner                                 92.0
# iron_100g                                   91.0
# trans-fat_100g                              91.0
# calcium_100g                                90.0
# vitamin-c_100g                              78.0
# vitamin-a_100g                              77.0
# additives_en                                67.0
# brands                                      59.0
# dtype: float64

# %% [markdown]
# La comparaison démontre la dangerosité d'une restriction uniquement à la France, la qualité des données, ainsi que le volume ne sont pas suffisants.\
# **Aucune restriction sur le pays de vente ne sera appliquée, maintenant voyons comment traiter les valeurs manquantes.**

# %%
openfoodfacts.dropna(subset=['ingredients_that_may_be_from_palm_oil_n',
                             'ingredients_from_palm_oil_n', 'additives_n',
                             'nova_group', 'fiber_100g', 'iron_100g', 'trans-fat_100g',
                             'calcium_100g', 'vitamin-c_100g', 'vitamin-a_100g',
                             'additives_en'], axis=0, how='any', inplace=True)

# %%
display(openfoodfacts.shape)
display(missing_value_clean(openfoodfacts))
# Out:
# (10521, 38)
# nutrition-score-fr_100g                    100.0
# iron_100g                                  100.0
# pnns_groups_1                              100.0
# nova_group                                 100.0
# nutriscore_grade                           100.0
# ingredients_that_may_be_from_palm_oil_n    100.0
# ingredients_from_palm_oil_n                100.0
# additives_en                               100.0
# additives_n                                100.0
# ingredients_text                           100.0
# countries_en                               100.0
# categories                                 100.0
# product_name                               100.0
# last_modified_t                            100.0
# created_t                                  100.0
# creator                                    100.0
# url                                        100.0
# pnns_groups_2                              100.0
# states                                     100.0
# sugars_100g                                100.0
# main_category                              100.0
# calcium_100g                               100.0
# vitamin-c_100g                             100.0
# vitamin-a_100g                             100.0
# sodium_100g                                100.0
# salt_100g                                  100.0
# proteins_100g                              100.0
# fiber_100g                                 100.0
# code                                       100.0
# carbohydrates_100g                         100.0
# cholesterol_100g                           100.0
# trans-fat_100g                             100.0
# saturated-fat_100g                         100.0
# fat_100g                                   100.0
# energy_100g                                100.0
# main_category_en                           100.0
# brand_owner                                 99.0
# brands                                      64.0
# dtype: float64

# %% [markdown]
# **L'échantillon de travail est optimal, plus de 10000 observations avec des données disponibles en totalité sur nos variables clés.**

# %%
openfoodfacts.rename(columns={'vitamin-c_100g': 'vitamin_c_100g', 'vitamin-a_100g': 'vitamin_a_100g', 
                  'nutrition-score-fr_100g': 'nutrition_score_fr_100g',
                  'trans-fat_100g': 'trans_fat_100g', 'saturated-fat_100g': 'saturated_fat_100g'}
                     , inplace=True)

# %%
openfoodfacts.to_csv('p3_00_data/df.csv', sep=';', encoding='utf-8')
